# %% [markdown]
# # EPA CompTox Chemistry Dashboard
#
# Lookup CAS numbers in EPA CompTox Dashboard.
#
# See: https://comptox.epa.gov/dashboard.

# %%
import logging

import pandas as pd

from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
from rdkit.Chem import Descriptors
PandasTools.RenderImagesInAllDataFrames()

from tqdm import tqdm_notebook
tqdm_notebook().pandas()

# %%
# Set up a logger object...

logger = logging.getLogger(__name__)
handler = logging.StreamHandler()
handler.setFormatter(logging.Formatter('[%(asctime)s %(name)s %(levelname)s] %(message)s', datefmt='%d/%m/%y %H:%M:%S'))
logger.addHandler(handler)
logger.setLevel(logging.INFO)

# %%
from EPA import comptox_lookup, comptox_link

# %% [markdown]
# ### Config

# %% [markdown]
# ### Reload CAS numbers

# %%
#cas_numbers = open('cas_numbers.txt', 'r').read().strip().split('\n')
filename = "C:\\Users\\bet\\Documents\\Inditex\\Compound inventory\\Annotated compounds\\REACH\\AnnexVI_inventory\\20170516\\annex_vi_clp_table_en.split.TallAndSkinny.tsv"
with open(filename, encoding='utf8') as infile:
    cas_numbers = set([x.split('\t')[4] for x in infile])

len(cas_numbers)
# Out:
# 3962

# %% [markdown]
# ### Lookup CAS numbers

# %%
records = [y for y in (comptox_lookup(x) for x in tqdm_notebook(cas_numbers)) if y is not None]

len(records)
# Out:
# CAS number '': problem extracting name.
# CAS number '' (name = 'None'): no structure available.
# CAS number '68919-02-8' (name = 'Gases, petroleum, fluidized catalytic cracker fractionation off'): no structure available.
# CAS number '64741-65-7' (name = 'Naphtha, petroleum, heavy alkylate'): no structure available.
# CAS number '68308-03-2' (name = 'Tail gas, petroleum, gas oil catalytic cracking absorber'): no structure available.
# CAS number '8065-36-9' (name = 'Bufencarb'): no structure available.
# CAS number '70592-77-7' (name = 'Distillates, petroleum, light vacuum'): no structure available.
# CAS number '68476-32-4' (name = 'Fuel oil, residues-straight-run gas oils, high-sulfur'): no structure available.
# CAS number '68919-39-1' (name = 'Natural gas condensates'): no structure available.
# CAS number '68308-10-1' (name = 'Tail gas, petroleum, straight-run distillate hydrodesulfurizer, hydrogen sulfide-free'): no structure available.
# CAS number '65996-92-1' (name = 'Distillates, coal tar'): no structure available.
# CAS number '68513-63-3' (name = 'Distillates, petroleum, catalytic reformed straight-run naphtha overheads'): no structure available.
# CAS number '1330-20-7' (name = 'Xylenes'): no structure available.
# CAS number '64741-60-2' (name = 'Distillates, petroleum, intermediate catalytic cracked'): no structure available.
# CAS number '68410-71-9' (name = 'Raffinates, petroleum, catalytic reformer ethylene glycol-water countercurrent exts.'): no structure available.
# CAS number '26471-62-5' (name = 'Toluene diisocyanate'): no structure available.
# CAS number '68410-96-8' (name = 'Distillates, petroleum, hydrotreated middle, intermediate boiling'): no structure available.
# CAS number '64742-03-6' (name = 'Extracts, petroleum, light naphthenic distillate solvent'): no structure available.
# CAS number '68919-09-5' (name = 'Gases, petroleum, straight-run naphtha catalytic reforming off'): no structure available.
# CAS number '68606-11-1' (name = 'Gasoline, straight-run, topping-plant'): no structure available.
# CAS number '15892-23-6': deleted; CAS number actually found = '78-92-2'.
# CAS number '68477-81-6' (name = 'Gases, petroleum, C6-8 catalytic reformer'): no structure available.
# CAS number '8006-64-2' (name = 'Turpentine oils'): no structure available.
# CAS number '88230-35-7' (name = 'Hexanol, acetate, branched and linear'): no structure available.
# CAS number '64742-59-2' (name = 'Gas oils, petroleum, hydrotreated vacuum'): no structure available.
# CAS number '85535-84-8' (name = 'C10-13 chloro alkanes'): no structure available.
# CAS number '147732-60-3' (name = 'Benzene, 1,1'-oxybis-, sec-hexyl derivs., sulfonated, sodium salts'): no structure available.
# CAS number '68477-55-4' (name = 'Distillates (petroleum), steam-cracked, C5-10 fraction, mixed with light steam-cracked petroleum naphtha C5 fraction'): no structure available.
# CAS number '64741-54-4' (name = 'Naphtha, petroleum, heavy catalytic cracked'): no structure available.
# CAS number '8030-30-6' (name = 'Naphtha'): no structure available.
# CAS number '65996-89-6' (name = 'Tar, coal, high-temp.'): no structure available.
# CAS number '77536-67-5' (name = 'Asbestos, anthophyllite'): no structure available.
# CAS number '61790-33-8' (name = 'Amines, tallow alkyl'): no structure available.
# CAS number '68477-71-4' (name = 'Gases, petroleum, catalytic-cracked gas oil depropanizer bottoms, C4-rich acid-free'): no structure available.
# CAS number '68308-04-3' (name = 'Tail gas, petroleum, gas recovery plant'): no structure available.
# CAS number '68990-61-4' (name = 'Tar, coal, high-temp., high-solids'): no structure available.
# CAS number '68919-37-9' (name = 'Naphtha, petroleum, full-range reformed'): no structure available.
# CAS number '68955-34-0' (name = 'Gases, petroleum, straight-run naphtha catalytic reformer stabilizer overhead'): no structure available.
# CAS number '72623-86-0' (name = 'Lubricating oils, petroleum, C15-30, hydrotreated neutral oil-based'): no structure available.
# CAS number '64742-23-0' (name = 'Naphtha, petroleum, chem. neutralized light'): no structure available.
# CAS number '68308-08-7' (name = 'Tail gas, petroleum, isomerized naphtha fractionation stabilizer'): no structure available.
# CAS number '68478-25-1' (name = 'Tail gas, petroleum, catalytic cracker refractionation absorber'): no structure available.
# CAS number '68477-53-2' (name = 'Distillates, petroleum, steam-cracked, C5-12 fraction'): no structure available.
# CAS number '68477-31-6' (name = 'Distillates, petroleum, catalytic reformer fractionator residue, low-boiling'): no structure available.
# CAS number '68609-97-2' (name = 'C12-14-Alkyl glycidyl ether'): no structure available.
# CAS number '68476-85-7' (name = 'Petroleum gases, liquefied'): no structure available.
# CAS number '25167-80-0' (name = 'Chlorophenol'): no structure available.
# CAS number '64741-95-3' (name = 'Residual oils, petroleum, solvent deasphalted'): no structure available.
# CAS number '179986-09-5' (name = 'Glycerides, mixed 3,5-bis(1,1-dimethylethyl)-4-hydroxybenzenepropanoyl and coco mono-, di- and tri-'): no structure available.
# CAS number '8050-09-7' (name = 'Rosin'): no structure available.
# CAS number '64742-62-7' (name = 'Residual oils, petroleum, solvent-dewaxed'): no structure available.
# CAS number '64742-11-6' (name = 'Extracts, petroleum, heavy naphthenic distillate solvent'): no structure available.
# CAS number '68513-16-6' (name = 'Gases, petroleum, hydrocracking depropanizer off, hydrocarbon-rich'): no structure available.
# CAS number '68477-65-6' (name = 'Gases, petroleum, amine system feed'): no structure available.
# CAS number '68606-26-8' (name = 'Hydrocarbons, C3'): no structure available.
# CAS number '64741-63-5' (name = 'Naphtha, petroleum, light catalytic reformed'): no structure available.
# CAS number '64742-69-4' (name = 'Naphthenic oils, petroleum, catalytic dewaxed light'): no structure available.
# CAS number '64741-59-9' (name = 'Distillates, petroleum, light catalytic cracked'): no structure available.
# CAS number '76714-88-0': deleted; CAS number actually found = '83657-24-3'.
# CAS number '64741-55-5' (name = 'Naphtha, petroleum, light catalytic cracked'): no structure available.
# CAS number '68952-77-2' (name = 'Tail gas (petroleum), catalytic cracked distillate and naphtha stabilizer'): no structure available.
# CAS number '68478-12-6' (name = 'Residues, petroleum, butane splitter bottoms'): no structure available.
# CAS number '64741-74-8' (name = 'Naphtha, petroleum, light thermal cracked'): no structure available.
# CAS number '64742-14-9' (name = 'Distillates, petroleum, acid-treated light'): no structure available.
# CAS number '101316-83-0' (name = 'Tar, brown-coal'): no structure available.
# CAS number '68477-86-1' (name = 'Gases, petroleum, deethanizer overheads'): no structure available.
# CAS number '19372-20-4' (name = 'Diphosphoric acid, nickel(2+) salt (1:?)'): no structure available.
# CAS number '68607-30-7' (name = 'Residues, petroleum, topping plant, low-sulfur'): no structure available.
# CAS number '68308-09-8' (name = 'Tail gas, petroleum, light straight-run naphtha stabilizer, hydrogen sulfide-free'): no structure available.
# CAS number '25068-38-6' (name = 'Bisphenol A/ Epichlorohydrin resin'): no structure available.
# CAS number '68132-19-4' (name = 'Polyphosphoric acids, compds. with ethoxylated coco alkylamines'): no structure available.
# CAS number '68308-01-0' (name = 'Tail gas, petroleum, cracked distillate hydrotreater stripper'): no structure available.
# CAS number '68513-69-9' (name = 'Residues, petroleum, steam-cracked light'): no structure available.
# CAS number '64742-05-8' (name = 'Extracts, petroleum, light paraffinic distillate solvent'): no structure available.
# CAS number '68783-04-0' (name = 'Extracts (petroleum), solvent-refined heavy paraffinic distillate solvent'): no structure available.
# CAS number '68476-86-8' (name = 'Petroleum gases, liquefied, sweetened'): no structure available.
# CAS number '68478-33-1' (name = 'Tail gas, petroleum, saturate gas recovery plant, C1-2-rich'): no structure available.
# CAS number '68478-05-7' (name = 'Gases, petroleum, thermal cracking distn.'): no structure available.
# CAS number '68476-33-5' (name = 'Fuel oil, residual'): no structure available.
# CAS number '64741-42-0' (name = 'Naphtha, petroleum, full-range straight-run'): no structure available.
# CAS number '68478-01-3' (name = 'Gases, petroleum, reformer make-up, hydrogen-rich'): no structure available.
# CAS number '9014-01-1' (name = 'Subtilisin'): no structure available.
# CAS number '163879-69-4' (name = 'Benzoic acid, 3-amino-, diazotized, coupled with 6-amino-4-hydroxy-2-naphthalenesulfonic acid, diazotized (3-aminophenyl)phosphonic acid and diazotized 2,5-diethoxybenzenamine'): no structure available.
# CAS number '8052-41-3' (name = 'Stoddard solvent'): no structure available.
# CAS number '68477-87-2' (name = 'Gases, petroleum, deisobutanizer tower overheads'): no structure available.
# CAS number '68333-22-2' (name = 'Residues, petroleum, atmospheric'): no structure available.
# CAS number '68602-83-5' (name = 'Gases, petroleum, C1-5, wet'): no structure available.
# CAS number '68477-80-5' (name = 'Gases, petroleum, C6-8 catalytic reformer recycle'): no structure available.
# CAS number '68333-26-6' (name = 'Clarified oils, petroleum, hydrodesulfurized catalytic cracked'): no structure available.
# CAS number '68919-07-3' (name = 'Gases, petroleum, platformer stabilizer off, light ends fractionation'): no structure available.
# CAS number '64741-83-9' (name = 'Naphtha, petroleum, heavy thermal cracked'): no structure available.
# CAS number '64742-83-2' (name = 'Naphtha, petroleum, light steam-cracked'): no structure available.
# CAS number '68477-23-6' (name = 'Tar acids, residues, distillates, first-cut'): no structure available.
# CAS number '202420-04-0' (name = '1H-Benzotriazole, C-chloro-C-methyl-, sodium salt (1:1)'): no structure available.
# CAS number '8006-61-9' (name = 'Natural gasoline'): no structure available.
# CAS number '68478-16-0' (name = 'Residual oils, petroleum, deisobutanizer tower'): no structure available.
# CAS number '12001-29-5' (name = 'Asbestos, chrysotile'): no structure available.
# CAS number '68911-59-1' (name = 'Gases, petroleum, hydrotreated sour kerosine flash drum'): no structure available.
# CAS number '68514-79-4' (name = 'Petroleum products, hydrofiner-powerformer reformates'): no structure available.
# CAS number '8007-45-2' (name = 'Coal tar'): no structure available.
# CAS number '12035-39-1' (name = 'Nickel titanium oxide (NiTiO3)'): no structure available.
# CAS number '64742-90-1' (name = 'Residues, petroleum, steam-cracked'): no structure available.
# CAS number '90640-80-5' (name = 'Anthracene oil'): no structure available.
# CAS number '64742-29-6' (name = 'Gas oils, petroleum, chemically neutralized'): no structure available.
# CAS number '2155-30-8': deleted; CAS number actually found = '547-64-8'.
# CAS number '64742-48-9' (name = 'Naphtha, petroleum, hydrotreated heavy'): no structure available.
# CAS number '64741-75-9' (name = 'Residues, petroleum, hydrocracked'): no structure available.
# CAS number '68553-00-4' (name = 'Fuel oil, No. 6'): no structure available.
# CAS number '68921-09-5' (name = 'Distillates, petroleum, naphtha unifiner stripper'): no structure available.
# CAS number '68476-31-3' (name = 'Fuel oil, No. 4'): no structure available.
# CAS number '68477-54-3' (name = 'Distillates, petroleum, steam-cracked, C8-12 fraction'): no structure available.
# CAS number '64742-54-7' (name = 'Distillates, petroleum, hydrotreated heavy paraffinic'): no structure available.
# CAS number '68606-25-7' (name = 'Hydrocarbons, C2-4'): no structure available.
# CAS number '68476-42-6' (name = 'Hydrocarbons, C4-5'): no structure available.
# CAS number '68477-83-8' (name = 'Gases, petroleum, C3-5 olefinic-paraffinic alkylation feed'): no structure available.
# CAS number '101631-19-0' (name = 'Kerosine (petroleum), hydrotreated'): no structure available.
# CAS number '68955-29-3' (name = 'Distillates, petroleum, light thermal cracked, debutanized arom.'): no structure available.
# CAS number '68477-99-6' (name = 'Gases, petroleum, isomerized naphtha fractionater, C4-rich, hydrogen sulfide-free'): no structure available.
# CAS number '25550-51-0' (name = 'Methylhexahydrophthalic anhydride'): no structure available.
# CAS number '68919-04-0' (name = 'Gases, petroleum, heavy distillate hydrotreater desulfurization stripper off'): no structure available.
# CAS number '68512-61-8' (name = 'Residues (petroleum), heavy coker and light vacuum'): no structure available.
# CAS number '68188-48-7' (name = 'Distillates, coal-petroleum, condensed-ring arom.'): no structure available.
# CAS number '68478-22-8' (name = 'Tail gas (petroleum), catalytic cracked naphtha stabilization absorber'): no structure available.
# CAS number '6369-59-1' (name = 'p-Toluenediamine sulfate'): no structure available.
# CAS number '68425-29-6' (name = 'Distillates (petroleum), naphtha-raffinate pyrolyzate-derived, gasoline-blending'): no structure available.
# CAS number '68333-25-5' (name = 'Distillates, petroleum, hydrodesulfurized light catalytic cracked'): no structure available.
# CAS number '12172-73-5' (name = 'Asbestos, amosite'): no structure available.
# CAS number '64742-36-5' (name = 'Distillates, petroleum, clay-treated heavy paraffinic'): no structure available.
# CAS number '65996-90-9' (name = 'Tar, coal, low-temp.'): no structure available.
# CAS number '68477-85-0' (name = 'Gases, petroleum, C4-rich'): no structure available.
# CAS number '8009-03-8' (name = 'Petrolatum'): no structure available.
# CAS number '64742-91-2' (name = 'Distillates, petroleum, steam-cracked'): no structure available.
# CAS number '68475-57-0' (name = 'Alkanes, C1-2'): no structure available.
# CAS number '68477-89-4' (name = 'Distillates, petroleum, depentanizer overheads'): no structure available.
# CAS number '29590-42-9' (name = 'Isooctyl acrylate'): no structure available.
# CAS number '34090-76-1' (name = '4-Methyltetrahydrophthalic anhydride'): no structure available.
# CAS number '64742-53-6' (name = 'Distillates, petroleum, hydrotreated light naphthenic'): no structure available.
# CAS number '71888-89-6' (name = '1,2-Benzenedicarboxylic acid, di-C6-8-branched alkyl esters, C7-rich'): no structure available.
# CAS number '64742-31-0' (name = 'Distillates, petroleum, chemically neutralized light'): no structure available.
# CAS number '68513-15-5' (name = 'Gases, petroleum, full-range straight-run naphtha dehexanizer off'): no structure available.
# CAS number '94114-58-6' (name = 'Fuels, jet aircraft, coal solvent extn., hydrocracked hydrogenated'): no structure available.
# CAS number '84852-15-3' (name = '4-Nonylphenol, branched'): no structure available.
# CAS number '68478-24-0' (name = 'Tail gas, petroleum, catalytic cracker, catalytic reformer and hydrodesulfurizer combined fractionater'): no structure available.
# CAS number '68477-68-9' (name = 'Gases, petroleum, blend oil, hydrogen-nitrogen-rich'): no structure available.
# CAS number '64742-15-0' (name = 'Naphtha, petroleum, acid-treated'): no structure available.
# CAS number '64741-69-1' (name = 'Naphtha, petroleum, light hydrocracked'): no structure available.
# CAS number '68527-22-0' (name = 'Naphtha, petroleum, clay-treated light straight-run'): no structure available.
# CAS number '64741-53-3' (name = 'Distillates, petroleum, heavy naphthenic'): no structure available.
# CAS number '68186-89-0' (name = 'C.I. Pigment Black 25'): no structure available.
# CAS number '68477-98-5' (name = 'Gases, petroleum, hydrotreater blend oil recycle, hydrogen-nitrogen-rich'): no structure available.
# CAS number '68919-10-8' (name = 'Gases, petroleum, straight-run stabilizer off'): no structure available.
# CAS number '70321-67-4' (name = 'Tar bases, coal, quinoline derivs. fraction'): no structure available.
# CAS number '68478-15-9' (name = 'Residues, petroleum, C6-8 catalytic reformer'): no structure available.
# CAS number '64741-77-1' (name = 'Distillates, petroleum, light hydrocracked'): no structure available.
# CAS number '70321-80-1' (name = 'Creosote oil, low-boiling distillate'): no structure available.
# CAS number '68937-63-3' (name = 'Extract oils (coal), tar base, collidine fraction'): no structure available.
# CAS number '60-57-1' (name = 'Dieldrin'): will regenerate SMILES from conntab.
# CAS number '64741-81-7' (name = 'Distillates, petroleum, heavy thermal cracked'): no structure available.
# CAS number '65996-86-3' (name = 'Extract oils, coal, tar base'): no structure available.
# CAS number '68477-34-9' (name = 'Distillates, petroleum, C3-5, 2-methyl-2-butene-rich'): no structure available.
# CAS number '72623-85-9' (name = 'Lubricating oils, petroleum, C20-50, hydrotreated neutral oil-based, high-viscosity'): no structure available.
# CAS number '65996-87-4' (name = 'Extract residues, coal, tar oil alk.'): no structure available.
# CAS number '64742-28-5' (name = 'Distillates (petroleum), chemically neutralized light paraffinic'): no structure available.
# CAS number '12510-42-8' (name = 'Erionite'): no structure available.
# CAS number '64741-51-1' (name = 'Distillates, petroleum, heavy paraffinic'): no structure available.
# CAS number '92062-15-2' (name = 'Solvent naphtha, (petroleum), hydrotreated light, naphthenic'): no structure available.
# CAS number '139189-30-3' (name = 'Phosphoric acid, P,P'-1,3-phenylene P,P,P',P'-tetrakis(2,6-dimethylphenyl) ester'): no structure available.
# CAS number '8001-58-9' (name = 'Creosote'): no structure available.
# CAS number '68527-18-4' (name = 'Gas oils, petroleum, steam-cracked'): no structure available.
# CAS number '68555-24-8' (name = 'Tar acids, cresylic, residues'): no structure available.
# CAS number '8052-10-6' (name = 'Tall-oil rosin'): no structure available.
# CAS number '68477-82-7' (name = 'Gases, petroleum, C6-8 catalytic reformer recycle, hydrogen-rich'): no structure available.
# CAS number '65996-79-4' (name = 'Solvent naphtha, coal'): no structure available.
# CAS number '64742-35-4' (name = 'Distillates, petroleum, chemically neutralized light naphthenic'): no structure available.
# CAS number '68919-11-9' (name = 'Gases (petroleum), tar stripper off'): no structure available.
# CAS number '68515-50-4' (name = '1,2-Benzenedicarboxylic acid, dihexyl ester, branched and linear'): no structure available.
# CAS number '7705-14-8': deleted; CAS number actually found = '138-86-3'.
# CAS number '68477-84-9' (name = 'Gases (petroleum), C2-return stream'): no structure available.
# CAS number '64741-67-9' (name = 'Residues, petroleum, catalytic reformer fractionator'): no structure available.
# CAS number '32534-81-9' (name = 'Pentabromodiphenyl ether'): no structure available.
# CAS number '68477-95-2' (name = 'Gases, petroleum, Girbatol unit feed'): no structure available.
# CAS number '70592-76-6' (name = 'Distillates, petroleum, intermediate vacuum'): no structure available.
# CAS number '68477-79-2' (name = 'Gases, petroleum, catalytic reformer, C1-4-rich'): no structure available.
# CAS number '68514-15-8' (name = 'Gasoline, vapor-recovery'): no structure available.
# CAS number '64742-30-9' (name = 'Distillates, petroleum, chemically neutralized middle'): no structure available.
# CAS number '68513-18-8' (name = 'Gases, petroleum, reformer effluent high-pressure flash drum off'): no structure available.
# CAS number '68515-42-4' (name = '1,2-Benzenedicarboxylic acid, di-C7-11-branched and linear alkyl esters'): no structure available.
# CAS number '8001-35-2' (name = 'Toxaphene'): no structure available.
# CAS number '65996-78-3' (name = 'Light oil, coal, coke-oven'): no structure available.
# CAS number '25321-14-6' (name = 'Dinitrotoluene'): no structure available.
# CAS number '68476-50-6' (name = 'Hydrocarbons, C.gtoreq.5, C5-6-rich'): no structure available.
# CAS number '92045-43-7' (name = 'Lubricating oils (petroleum), hydrocracked nonarom. solvent-deparaffined'): no structure available.
# CAS number '68476-30-2' (name = 'Fuel oil, No. 2'): no structure available.
# CAS number '9012-54-8' (name = 'Hemicellulase'): no structure available.
# CAS number '68476-29-9' (name = 'Fuel gases, crude oil distillates'): no structure available.
# CAS number '68476-49-3' (name = 'Hydrocarbons, C2-4, C3-rich'): no structure available.
# CAS number '64741-48-6' (name = 'Natural gas, petroleum, raw liq. mix'): no structure available.
# CAS number '68512-91-4' (name = 'Hydrocarbons, C3-4-rich, petroleum distillates'): no structure available.
# CAS number '8018-01-7' (name = 'Mancozeb'): no structure available.
# CAS number '32536-52-0' (name = 'Octabromodiphenyl ether'): no structure available.
# CAS number '39300-45-3' (name = 'Dinocap'): no structure available.
# CAS number '68783-09-5' (name = 'Naphtha (petroleum), catalytic cracked light distd.'): no structure available.
# CAS number '151006-62-1' (name = '1-Dodecene, trimer, hydrogenated'): no structure available.
# CAS number '1319-77-3' (name = 'Cresol'): no structure available.
# CAS number '68476-47-1' (name = 'Hydrocarbons, C2-6, C6-8 catalytic reformer'): no structure available.
# CAS number '68513-17-7' (name = 'Gases, petroleum, light straight-run naphtha stabilizer off'): no structure available.
# CAS number '68919-06-2' (name = 'Gases, petroleum, naphtha unifiner desulfurization stripper off'): no structure available.
# CAS number '64742-78-5' (name = 'Residues, petroleum, hydrodesulfurized atmospheric tower'): no structure available.
# CAS number '64741-70-4' (name = 'Naphtha, petroleum, isomerization'): no structure available.
# CAS number '12035-72-2' (name = 'Nickel subsulfide'): no structure available.
# CAS number '64742-27-4' (name = 'Distillates (petroleum), chemically neutralized heavy paraffinic'): no structure available.
# CAS number '68477-66-7' (name = 'Gases, petroleum, benzene unit hydrodesulfurizer off'): no structure available.
# CAS number '64741-86-2' (name = 'Distillates, petroleum, sweetened middle'): no structure available.
# CAS number '64741-45-3' (name = 'Residues, petroleum, atm. tower'): no structure available.
# CAS number '64742-63-8' (name = 'Distillates, petroleum, solvent-dewaxed heavy naphthenic'): no structure available.
# CAS number '68783-06-2' (name = 'Gases, petroleum, hydrocracking low-pressure separator'): no structure available.
# CAS number '68603-03-2' (name = 'Distillates, petroleum, thermal cracked naphtha and gas oil, extractive'): no structure available.
# CAS number '80498-15-3' (name = 'Laccase'): no structure available.
# CAS number '68475-79-6' (name = 'Distillates, petroleum, catalytic reformed depentanizer'): no structure available.
# CAS number '68513-14-4' (name = 'Gases, petroleum, catalytic reformed straight-run naphtha stabilizer overheads'): no structure available.
# CAS number '15096-52-3' (name = 'Cryolite'): no structure available.
# CAS number '68475-70-7' (name = 'Aromatic hydrocarbons, C6-8, naphtha-raffinate pyrolyzate-derived'): no structure available.
# CAS number '25167-70-8' (name = '2,4,4-Trimethylpentene'): no structure available.
# CAS number '64742-18-3' (name = 'Distillates, petroleum, acid-treated heavy naphthenic'): no structure available.
# CAS number '68477-74-7' (name = 'Gases, petroleum, catalytic cracker'): no structure available.
# CAS number '68307-98-2' (name = 'Tail gas, petroleum, catalytic cracked distillate and catalytic cracked naphtha fractionation absorber'): no structure available.
# CAS number '68131-73-7' (name = 'Polyethylenepolyamine'): no structure available.
# CAS number '68514-36-3' (name = 'Hydrocarbons, C1-4, sweetened'): no structure available.
# CAS number '12222-04-7' (name = 'C.I. Direct Blue 199'): no structure available.
# CAS number '68478-26-2' (name = 'Tail gas, petroleum, catalytic reformed naphtha fractionation stabilizer'): no structure available.
# CAS number '68477-97-4' (name = 'Gases, petroleum, hydrogen-rich'): no structure available.
# CAS number '64742-52-5' (name = 'Distillates, petroleum, hydrotreated heavy naphthenic'): no structure available.
# CAS number '68513-87-1' (name = 'Tar bases, quinoline derivs.'): no structure available.
# CAS number '63449-41-2' (name = 'Benzyl-C8-18-alkyldimethylammonium chlorides'): no structure available.
# CAS number '68602-84-6' (name = 'Gases, petroleum, secondary absorber off, fluidized catalytic cracker overheads fractionater'): no structure available.
# CAS number '73138-82-6' (name = 'Resin acids and Rosin acids'): no structure available.
# CAS number '68333-27-7' (name = 'Distillates, petroleum, hydrodesulfurized intermediate catalytic cracked'): no structure available.
# CAS number '68911-58-0' (name = 'Gases, petroleum, hydrotreated sour kerosine depentanizer stabilizer off'): no structure available.
# CAS number '71302-79-9' (name = 'Fatty acids, linseed-oil, epoxidized, 2-ethylhexyl esters'): no structure available.
# CAS number '68478-28-4' (name = 'Tail gas, petroleum, catalytic reformed naphtha stabilizer'): no structure available.
# CAS number '68815-21-4' (name = 'Tar acids, cresylic, sodium salts, caustic solns.'): no structure available.
# CAS number '64741-73-7' (name = 'Distillates, petroleum, alkylate'): no structure available.
# CAS number '64742-96-7' (name = 'Solvent naphtha, petroleum, heavy aliph.'): no structure available.
# CAS number '68308-06-5' (name = 'Tail gas, petroleum, hydrodesulfurized distillate and hydrodesulfurized naphtha fractionator, acid-free'): no structure available.
# CAS number '68512-78-7' (name = 'Solvent naphtha, petroleum, light aromatic hydrotreated'): no structure available.
# CAS number '68478-34-2' (name = 'Tail gas, petroleum, vacuum residues thermal cracker'): no structure available.
# CAS number '65229-23-4' (name = 'Nickel boride phosphide'): no structure available.
# CAS number '68477-93-0' (name = 'Gases (petroleum), gas concn. reabsorber distn.'): no structure available.
# CAS number '9000-90-2' (name = 'alpha-Amylase'): no structure available.
# CAS number '64742-12-7' (name = 'Gas oils (petroleum), acid-treated'): no structure available.
# CAS number '68410-05-9' (name = 'Distillates, petroleum, straight-run light'): no structure available.
# CAS number '64742-94-5' (name = 'Solvent naphtha, petroleum, heavy arom.'): no structure available.
# CAS number '68952-80-7' (name = 'Tail gas, petroleum, straight-run naphtha hydrodesulfurizer'): no structure available.
# CAS number '68475-59-2' (name = 'Alkanes, C3-4'): no structure available.
# CAS number '151006-58-5' (name = '1-Dodecene, dimer with 1-decene, hydrogenated'): no structure available.
# CAS number '8065-48-3' (name = 'Demeton'): no structure available.
# CAS number '64742-04-7' (name = 'Extracts, petroleum, heavy paraffinic distillate solvent'): no structure available.
# CAS number '64742-68-3' (name = 'Naphthenic oils (petroleum), catalytic dewaxed heavy'): no structure available.
# CAS number '68477-90-7' (name = 'Gases, petroleum, depropanizer dry, propene-rich'): no structure available.
# CAS number '92062-33-4' (name = 'Tar bases, coal, picoline fraction'): no structure available.
# CAS number '68333-23-3' (name = 'Naphtha, petroleum, heavy coker'): no structure available.
# CAS number '68814-90-4' (name = 'Gases, petroleum, platformer products separator off'): no structure available.
# CAS number '68307-99-3' (name = 'Tail gas, petroleum, catalytic polymn. naphtha fractionation stabilizer'): no structure available.
# CAS number '68602-82-4' (name = 'Gases, petroleum, benzene unit hydrotreater depentenizer overheads'): no structure available.
# CAS number '64742-13-8' (name = 'Distillates, petroleum, acid-treated middle'): no structure available.
# CAS number '68514-31-8' (name = 'Hydrocarbons, C1-4'): no structure available.
# CAS number '68477-35-0' (name = 'Distillates, petroleum, C3-6, piperylene-rich'): no structure available.
# CAS number '12001-28-4' (name = 'Asbestos, crocidolite'): no structure available.
# CAS number '64741-98-6' (name = 'Extracts, petroleum, heavy naphtha solvent'): no structure available.
# CAS number '74499-35-7' (name = 'Phenol, (tetrapropenyl) derivs.'): no structure available.
# CAS number '68475-60-5' (name = 'Alkanes, C4-5'): no structure available.
# CAS number '68919-03-9' (name = 'Gases, petroleum, fluidized catalytic cracker scrubbing secondary absorber off'): no structure available.
# CAS number '61788-45-2' (name = 'Amines, hydrogenated tallow alkyl'): no structure available.
# CAS number '9002-07-7' (name = 'Trypsin'): no structure available.
# CAS number '68603-00-9' (name = 'Distillates, petroleum, thermal cracked naphtha and gas oil'): no structure available.
# CAS number '68955-33-9' (name = 'Gases, petroleum, sponge absorber off, fluidized catalytic cracker and gas oil desulfurizer overhead fractionation'): no structure available.
# CAS number '64742-57-0' (name = 'Residual oils, petroleum, hydrotreated'): no structure available.
# CAS number '68610-24-2' (name = 'C.I. Pigment Yellow 157'): no structure available.
# CAS number '69430-40-6' (name = 'Siloxanes and Silicones, di-Me, Me hydrogen, reaction products with 1,1,1,3,3,3-hexamethyldisiloxane and polypropylene glycol allyl Me ether'): no structure available.
# CAS number '68919-01-7' (name = 'Gases, petroleum, distillate unifiner desulfurization stripper off'): no structure available.
# CAS number '125643-61-0' (name = 'Benzenepropanoic acid, 3,5-bis(1,1-dimethylethyl)-4-hydroxy-, C7-9-branched alkyl esters'): no structure available.
# CAS number '68478-00-2' (name = 'Gases, petroleum, recycle, hydrogen-rich'): no structure available.
# CAS number '64741-96-4' (name = 'Distillates, petroleum, solvent-refined heavy naphthenic'): no structure available.
# CAS number '67375-30-8' (name = 'alpha-Cypermethrin'): will regenerate SMILES from conntab.
# CAS number '68477-38-3' (name = 'Distillates (petroleum), cracked steam-cracked petroleum distillates'): no structure available.
# CAS number '65996-85-2' (name = 'Tar acids, coal, crude'): no structure available.
# CAS number '68477-77-0' (name = 'Gases, petroleum, catalytic reformed naphtha stripper overheads'): no structure available.
# CAS number '107-01-7' (name = '2-Butene'): no structure available.
# CAS number '64742-73-0' (name = 'Naphtha, petroleum, hydrodesulfurized light'): no structure available.
# CAS number '64742-79-6' (name = 'Gas oils, petroleum, hydrodesulfurized'): no structure available.
# CAS number '182176-52-9' (name = 'Ethaneperoxoic acid, reaction products with 3,3,4,4,5,5,6,6,7,7,8,8,9,9,10,10,10-heptadecafluorodecyl thiocyanate and 3,3,4,4,5,5,6,6,7,7,8,8,8-tridecafluorooctyl thiocyanate'): no structure available.
# CAS number '68478-27-3' (name = 'Tail gas, petroleum, catalytic reformed naphtha separator'): no structure available.
# CAS number '73665-18-6' (name = 'Extract residues, coal, tar oil alk., naphthalene distn. residues'): no structure available.
# CAS number '11070-44-3' (name = 'Isomethyltetrahydrophthalic anhydride'): no structure available.
# CAS number '8002-05-9' (name = 'Petroleum'): no structure available.
# CAS number '8008-20-6' (name = 'Kerosine'): no structure available.
# CAS number '68478-30-8' (name = 'Tail gas, petroleum, hydrodesulfurized straight-run naphtha separator'): no structure available.
# CAS number '65232-89-5' (name = 'Vanadium hydroxide oxide phosphate'): no structure available.
# CAS number '65996-88-5' (name = 'Benzol forerunnings (coal)'): no structure available.
# CAS number '70321-79-8' (name = 'Creosote oil, high-boiling distillate'): no structure available.
# CAS number '64741-64-6' (name = 'Naphtha, petroleum, full-range alkylate'): no structure available.
# CAS number '68603-08-7' (name = 'Naphtha, petroleum, arom.-contg.'): no structure available.
# CAS number '68475-80-9' (name = 'Distillates, petroleum, light steam-cracked naphtha'): no structure available.
# CAS number '64742-47-8' (name = 'Distillates, petroleum, hydrotreated light'): no structure available.
# CAS number '68516-20-1' (name = 'Naphtha, petroleum, steam-cracked middle arom.'): no structure available.
# CAS number '68919-12-0' (name = 'Gases, petroleum, unifiner stripper off'): no structure available.
# CAS number '68955-27-1' (name = 'Distillates, petroleum, petroleum residues vacuum'): no structure available.
# CAS number '68308-05-4' (name = 'Tail gas, petroleum, gas recovery plant deethanizer'): no structure available.
# CAS number '64742-70-7' (name = 'Paraffin oils, petroleum, catalytic dewaxed heavy'): no structure available.
# CAS number '64742-34-3' (name = 'Distillates, petroleum, chemically neutralized heavy naphthenic'): no structure available.
# CAS number '77536-66-4' (name = 'Asbestos, actinolite'): no structure available.
# CAS number '67891-79-6' (name = 'Distillates, petroleum, heavy arom.'): no structure available.
# CAS number '64741-50-0' (name = 'Distillates, petroleum, light paraffinic'): no structure available.
# CAS number '68410-98-0' (name = 'Distillates, petroleum, hydrotreated heavy naphtha, deisohexanizer overheads'): no structure available.
# CAS number '64741-91-9' (name = 'Distillates, petroleum, solvent-refined middle'): no structure available.
# CAS number '64742-19-4' (name = 'Distillates, petroleum, acid-treated light naphthenic'): no structure available.
# CAS number '68513-66-6' (name = 'Residues, petroleum, alkylation splitter, C4-rich'): no structure available.
# CAS number '11138-47-9' (name = 'Sodium perborate'): no structure available.
# CAS number '64741-52-2' (name = 'Distillates, petroleum, light naphthenic'): no structure available.
# CAS number '91465-08-6' (name = 'lambda-Cyhalothrin'): will regenerate SMILES from conntab.
# CAS number '68334-30-5' (name = 'Fuels, diesel'): no structure available.
# CAS number '64742-89-8' (name = 'Solvent naphtha, petroleum, light aliph.'): no structure available.
# CAS number '68475-58-1' (name = 'Alkanes, C2-3'): no structure available.
# CAS number '64742-95-6' (name = 'Light aromatic solvent naphtha (petroleum)'): no structure available.
# CAS number '8051-02-3' (name = 'Sabadilla alkaloids'): no structure available.
# CAS number '68606-27-9' (name = 'Gases, petroleum, alkylation feed'): no structure available.
# CAS number '72-20-8' (name = 'Endrin'): will regenerate SMILES from conntab.
# CAS number '64741-57-7' (name = 'Gas oils, petroleum, heavy vacuum'): no structure available.
# CAS number '68477-75-8' (name = 'Gases, petroleum, catalytic cracker, C1-5-rich'): no structure available.
# CAS number '68477-29-2' (name = 'Distillates, petroleum, catalytic reformer fractionator residue, high-boiling'): no structure available.
# CAS number '64742-45-6' (name = 'Distillates, petroleum, clay-treated light naphthenic'): no structure available.
# CAS number '68187-57-5' (name = 'Pitch, coal tar-petroleum'): no structure available.
# CAS number '68606-10-0' (name = 'Gasoline, pyrolysis, debutanizer bottoms'): no structure available.
# CAS number '64741-84-0' (name = 'Naphtha, petroleum, solvent-refined light'): no structure available.
# CAS number '68919-00-6' (name = 'Gases, petroleum, dehexanizer off'): no structure available.
# CAS number '68952-82-9' (name = 'Tail gas, petroleum, thermal cracked hydrocarbon fractionation stabilizer, petroleum coking'): no structure available.
# CAS number '64742-82-1' (name = 'Naphtha, petroleum, hydrodesulfurized heavy'): no structure available.
# CAS number '1336-36-3' (name = 'Polychlorinated biphenyls'): no structure available.
# CAS number '64741-41-9' (name = 'Naphtha, petroleum, heavy straight-run'): no structure available.
# CAS number '25168-05-2' (name = 'Chlorotoluene'): no structure available.
# CAS number '7085-19-0': deleted; CAS number actually found = '93-65-2'.
# CAS number '25154-52-3' (name = 'Nonylphenol (mixed)'): no structure available.
# CAS number '68607-11-4' (name = 'Petroleum products, refinery gases'): no structure available.
# CAS number '64741-66-8' (name = 'Naphtha, petroleum, light alkylate'): no structure available.
# CAS number '68919-05-1' (name = 'Gases, petroleum, light straight run gasoline fractionation stabilizer off'): no structure available.
# CAS number '87818-31-3' (name = 'Cinmethylin'): will regenerate SMILES from conntab.
# CAS number '1300-71-6' (name = 'Dimethylphenol'): no structure available.
# CAS number '64742-55-8' (name = 'Distillates, petroleum, hydrotreated light paraffinic'): no structure available.
# CAS number '151006-59-6' (name = '1-Dodecene, trimer with 1-decene, hydrogenated'): no structure available.
# CAS number '67891-80-9' (name = 'Distillates, petroleum, light arom.'): no structure available.
# CAS number '64742-80-9' (name = 'Distillates, petroleum, hydrodesulfurized middle'): no structure available.
# CAS number '68477-92-9' (name = 'Gases, petroleum, dry sour, gas-concn.-unit-off'): no structure available.
# CAS number '69012-50-6' (name = 'Matte, nickel'): no structure available.
# CAS number '68783-12-0' (name = 'Naphtha, petroleum, unsweetened'): no structure available.
# CAS number '68477-40-7' (name = 'Distillates, petroleum, cracked stripped steam-cracked petroleum distillates, C10-12 fraction'): no structure available.
# CAS number '68476-46-0' (name = 'Hydrocarbons, C3-11, catalytic cracker distillates'): no structure available.
# CAS number '68783-66-4' (name = 'Naphtha, petroleum, light, sweetened'): no structure available.
# CAS number '68527-23-1' (name = 'Naphtha, petroleum, light steam-cracked arom.'): no structure available.
# CAS number '68918-99-0' (name = 'Gases, petroleum, crude oil fractionation off'): no structure available.
# CAS number '64742-67-2' (name = 'Foots oil, petroleum'): no structure available.
# CAS number '85535-85-9' (name = 'Cercelor S 52'): no structure available.
# CAS number '68513-02-0' (name = 'Naphtha, petroleum, full-range coker'): no structure available.
# CAS number '64742-88-7' (name = 'Stoddard solvent IIC'): no structure available.
# CAS number '68477-39-4' (name = 'Distillates (petroleum), cracked stripped steam-cracked petroleum distillates, C8-10 fraction'): no structure available.
# CAS number '68783-65-3' (name = 'Gases, petroleum, C2-4, sweetened'): no structure available.
# CAS number '64742-75-2' (name = 'Naphthenic oils (petroleum), complex dewaxed heavy'): no structure available.
# CAS number '68783-08-4' (name = 'Gas oils, petroleum, heavy atmospheric'): no structure available.
# CAS number '64741-88-4' (name = 'Distillates, petroleum, solvent-refined heavy paraffinic'): no structure available.
# CAS number '68921-08-4' (name = 'Distillates, petroleum, light straight-run gasoline fractionation stabilizer overheads'): no structure available.
# CAS number '68478-13-7' (name = 'Residues, petroleum, catalytic reformer fractionator residue distn.'): no structure available.
# CAS number '64742-38-7' (name = 'Distillates, petroleum, clay-treated middle'): no structure available.
# CAS number '68308-07-6' (name = 'Tail gas, petroleum, hydrodesulfurized vacuum gas oil stripper, hydrogen sulfide-free'): no structure available.
# CAS number '68527-15-1' (name = 'Gases, petroleum, oil refinery gas distn. off'): no structure available.
# CAS number '64742-22-9' (name = 'Naphtha, petroleum, chem. neutralized heavy'): no structure available.
# CAS number '68515-84-4' (name = 'Olivine, nickel green'): no structure available.
# CAS number '90640-86-1' (name = 'Distillates, coal tar, heavy oils'): no structure available.
# CAS number '68527-26-4' (name = 'Naphtha, petroleum, light steam-cracked, debenzenized'): no structure available.
# CAS number '65996-84-1' (name = 'Tar bases, coal, crude'): no structure available.
# CAS number '192268-65-8' (name = 'Phosphorothioic acid, O,O,O-triphenyl esters, tert-Bu derivs.'): no structure available.
# CAS number '68477-30-5' (name = 'Distillates (petroleum), catalytic reformer fractionator residue, intermediate-boiling'): no structure available.
# CAS number '68130-19-8' (name = 'Silicic acid, lead nickel salt'): no structure available.
# CAS number '68512-62-9' (name = 'Residues, petroleum, light vacuum'): no structure available.
# CAS number '187412-41-5' (name = 'Fatty acids, C6-10, mixed esters with adipic acid, dipentaerythritol, heptanoic acid, isostearic acid and pentaerythritol'): no structure available.
# CAS number '68955-36-2' (name = 'Residues, petroleum, steam-cracked, resinous'): no structure available.
# CAS number '64742-49-0' (name = 'Naphtha, petroleum, hydrotreated light'): no structure available.
# CAS number '32289-58-0' (name = 'Polihexanide'): no structure available.
# CAS number '68478-02-4' (name = 'Gases, petroleum, reforming hydrotreater'): no structure available.
# CAS number '27083-27-8' (name = '1,6-Hexanediamine, polymer with N,N'''-1,6-hexanediylbis[N'-cyanoguanidine], hydrochloride'): no structure available.
# CAS number '64742-86-5' (name = 'Gas oils, petroleum, hydrodesulfurized heavy vacuum'): no structure available.
# CAS number '92045-37-9' (name = 'Kerosine (petroleum), straight-run wide-cut'): no structure available.
# CAS number '68919-20-0' (name = 'Gases, petroleum, fluidized catalytic cracker splitter overheads'): no structure available.
# CAS number '64742-44-5' (name = 'Distillates, petroleum, clay-treated heavy naphthenic'): no structure available.
# CAS number '17169-61-8' (name = 'Phosphoric acid, calcium nickel salt (1:?:?)'): no structure available.
# CAS number '68527-21-9' (name = 'Naphtha, petroleum, clay-treated full-range straight-run'): no structure available.
# CAS number '68476-55-1' (name = 'Hydrocarbons, C5-rich'): no structure available.
# CAS number '78587-05-0' (name = 'Hexythiazox'): will regenerate SMILES from conntab.
# CAS number '9001-73-4' (name = 'Papain'): no structure available.
# CAS number '84777-06-0' (name = '1,2-Benzenedicarboxylic acid, dipentyl ester, branched and linear'): no structure available.
# CAS number '64741-47-5' (name = 'Natural gas condensates, petroleum'): no structure available.
# CAS number '65996-82-9' (name = 'Tar oils, coal'): no structure available.
# CAS number '64742-41-2' (name = 'Residual oils, petroleum, clay-treated'): no structure available.
# CAS number '68606-34-8' (name = 'Gases, petroleum, depropanizer bottoms fractionation off'): no structure available.
# CAS number '68476-40-4' (name = 'Hydrocarbons, C3-4'): no structure available.
# CAS number '9001-33-6' (name = 'Ficin'): no structure available.
# CAS number '68814-67-5' (name = 'Gases, petroleum, refinery'): no structure available.
# CAS number '68513-19-9' (name = 'Gases, petroleum, reformer effluent low-pressure flash drum off'): no structure available.
# CAS number '64741-97-5' (name = 'Distillates, petroleum, solvent-refined light naphthenic'): no structure available.
# CAS number '64741-46-4' (name = 'Naphtha, petroleum, light straight-run'): no structure available.
# CAS number '1344-81-6' (name = 'Calcium polysulfide'): no structure available.
# CAS number '68478-17-1' (name = 'Residues, petroleum, heavy coker gas oil and vacuum gas oil'): no structure available.
# CAS number '68527-16-2' (name = 'Hydrocarbons, C1-3'): no structure available.
# CAS number '68477-72-5' (name = 'Gases, petroleum, catalytic-cracked naphtha debutanizer bottoms, C3-5-rich'): no structure available.
# CAS number '68952-79-4' (name = 'Tail gas, petroleum, catalytic hydrodesulfurized naphtha separator'): no structure available.
# CAS number '68478-29-5' (name = 'Tail gas, petroleum, cracked distillate hydrotreater separator'): no structure available.
# CAS number '64742-56-9' (name = 'Distillates, petroleum, solvent-dewaxed light paraffinic'): no structure available.
# CAS number '64742-01-4' (name = 'Residual oils, petroleum, solvent-refined'): no structure available.
# CAS number '12262-58-7' (name = 'Cyclohexanone, peroxide'): no structure available.
# CAS number '64741-62-4' (name = 'Clarified oils, petroleum, catalytic cracked'): no structure available.
# CAS number '68783-00-6' (name = 'Extracts (petroleum), heavy naphthenic distillate solvent, arom. conc.'): no structure available.
# CAS number '68477-76-9' (name = 'Gases, petroleum, catalytic polymd. naphtha stabilizer overhead, C2-4-rich'): no structure available.
# CAS number '68479-98-1' (name = 'Diethylmethylbenzenediamine'): no structure available.
# CAS number '71751-41-2' (name = 'Abamectin'): no structure available.
# CAS number '70592-78-8' (name = 'Distillates, petroleum, vacuum'): no structure available.
# CAS number '166242-53-1' (name = 'Amines, hydrogenated tallow alkyl, reaction products with tetrakis(hydroxymethyl)phosphonium chloride and urea'): no structure available.
# CAS number '64742-37-6' (name = 'Distillates, petroleum, clay-treated light paraffinic'): no structure available.
# CAS number '25155-23-1' (name = 'TXP'): no structure available.
# CAS number '68919-08-4' (name = 'Gases, petroleum, preflash tower off, crude distn.'): no structure available.
# CAS number '68783-07-3' (name = 'Gases, petroleum, refinery blend'): no structure available.
# CAS number '68477-67-8' (name = 'Gases, petroleum, benzene unit recycle, hydrogen-rich'): no structure available.
# CAS number '25584-83-2' (name = 'Hydroxypropyl acrylate'): no structure available.
# CAS number '68476-26-6' (name = 'Fuel gases'): no structure available.
# CAS number '64742-76-3' (name = 'Naphthenic oils (petroleum), complex dewaxed light'): no structure available.
# CAS number '64741-78-2' (name = 'Naphtha, petroleum, heavy hydrocracked'): no structure available.
# CAS number '64741-89-5' (name = 'Distillates, petroleum, solvent-refined light paraffinic'): no structure available.
# CAS number '84030-86-4': deleted; CAS number actually found = '584-79-2'.
# CAS number '37199-66-9' (name = 'Potassium polysulfide'): no structure available.
# CAS number '64741-68-0' (name = 'Naphtha, petroleum, heavy catalytic reformed'): no structure available.
# CAS number '67564-91-4' (name = '(2R,6S)-Fenpropimorph'): will regenerate SMILES from conntab.
# CAS number '68391-11-7' (name = 'Pyridine, alkyl derivs.'): no structure available.
# CAS number '65996-93-2' (name = 'Pitch, coal tar, high-temp.'): no structure available.
# CAS number '869-59-0' (name = 'Tri-N-octyltin hydride'): will regenerate SMILES from conntab.
# CAS number '64741-90-8' (name = 'Gas oils, petroleum, solvent-refined'): no structure available.
# CAS number '206565-89-1' (name = 'Fatty acids, C18-unsatd., dimers, reaction products with 1-piperazineethanamine and tall-oil fatty acids'): no structure available.
# CAS number '1344-08-7' (name = 'Sodium sulfide [Na2(Sx)]'): no structure available.
# CAS number '68477-96-3' (name = 'Gases (petroleum), hydrogen absorber off'): no structure available.
# CAS number '68409-99-4' (name = 'Gases, petroleum, catalytic cracked overheads'): no structure available.
# CAS number '64741-76-0' (name = 'Distillates, petroleum, heavy hydrocracked'): no structure available.
# CAS number '68477-70-3' (name = 'Gases, petroleum, C2-3'): no structure available.
# CAS number '64742-20-7' (name = 'Distillates (petroleum), acid-treated heavy paraffinic'): no structure available.
# CAS number '26590-20-5' (name = '1,2,3,6-Tetrahydro-3-methylphthalic anhydride'): no structure available.
# CAS number '64742-64-9' (name = 'Distillates (petroleum), solvent-dewaxed light naphthenic'): no structure available.
# CAS number '68478-04-6' (name = 'Gases, petroleum, reforming hydrotreater make-up, hydrogen-rich'): no structure available.
# CAS number '151006-61-0' (name = '1-Dodecene, dimer, hydrogenated'): no structure available.
# CAS number '1321-64-8' (name = 'Pentachloronaphthalene'): no structure available.
# CAS number '68952-76-1' (name = 'Gases, petroleum, catalytic cracked naphtha debutanizer'): no structure available.
# CAS number '55965-84-9' (name = 'Bio-Perge'): no structure available.
# CAS number '64742-81-0' (name = 'Kerosine, petroleum, hydrodesulfurized'): no structure available.
# CAS number '68527-19-5' (name = 'Hydrocarbons, C1-4, debutanizer fraction'): no structure available.
# CAS number '93572-29-3' (name = 'Gasoline, C5-11, high-octane stabilized reformed'): no structure available.
# CAS number '64742-21-8' (name = 'Distillates (petroleum), acid-treated light paraffinic'): no structure available.
# CAS number '68477-73-6' (name = 'Gases, petroleum, catalytic cracked naphtha depropanizer overhead, C3-rich acid-free'): no structure available.
# CAS number '68308-12-3' (name = 'Tail gas, petroleum, vacuum gas oil hydrodesulfurizer, hydrogen sulfide-free'): no structure available.
# CAS number '86290-81-5' (name = 'Gasoline'): no structure available.
# CAS number '68308-00-9' (name = 'Tail gas (petroleum), catalytic reformed naphtha fractionation stabilizer, hydrogen sulfide-free'): no structure available.
# CAS number '68425-35-4' (name = 'Raffinates (petroleum), reformer, Lurgi unit-sepd.'): no structure available.
# CAS number '68478-03-5' (name = 'Gases, petroleum, reforming hydrotreater, hydrogen-methane-rich'): no structure available.
# CAS number '61789-28-4' (name = 'Creosote oil'): no structure available.
# CAS number '65996-83-0' (name = 'Extracts, coal tar oil alk.'): no structure available.
# CAS number '68527-27-5' (name = 'Naphtha, petroleum, full-range alkylate, butane-contg.'): no structure available.
# CAS number '8032-32-4' (name = 'Ligroine'): no structure available.
# CAS number '68955-35-1' (name = 'Naphtha, petroleum, catalytic reformed'): no structure available.
# CAS number '61789-60-4' (name = 'Pitch'): no structure available.
# CAS number '68513-03-1' (name = 'Naphtha, petroleum, light catalytic reformed, arom.-free'): no structure available.
# CAS number '68477-94-1' (name = 'Gases, petroleum, gas recovery plant depropanizer overheads'): no structure available.
# CAS number '68814-89-1' (name = 'Extracts (petroleum), heavy paraffinic distillates, solvent-deasphalted'): no structure available.
# CAS number '68410-97-9' (name = 'Distillates, petroleum, light distillate hydrotreating process, low-boiling'): no structure available.
# CAS number '68989-88-8' (name = 'Gases, petroleum, crude distn. and catalytic cracking'): no structure available.
# CAS number '64742-61-6' (name = 'Slack wax, petroleum'): no structure available.
# CAS number '26523-78-4' (name = 'Nonylphenolphosphite(3:1)'): no structure available.
# CAS number '68478-32-0' (name = 'Tail gas, petroleum, saturate gas plant mixed stream, C4-rich'): no structure available.
# CAS number '14507-36-9' (name = 'Phosphinic acid, nickel(2+) salt (2:1)'): no structure available.
# CAS number '68783-64-2' (name = 'Gases, petroleum, catalytic cracking'): no structure available.
# CAS number '68476-34-6' (name = 'Fuels, diesel, No. 2'): no structure available.
# CAS number '125613-45-8' (name = 'Siloxanes and Silicones, 5-hexenyl Me, hydroxy-terminated'): no structure available.
# CAS number '92045-53-9' (name = 'Naphtha, (petroleum) hydrodesulfurized light, dearomatized'): no structure available.
# CAS number '68477-33-8' (name = 'Gases, petroleum, C3-4, isobutane-rich'): no structure available.
# CAS number '68131-75-9' (name = 'Gases, petroleum, C3-4'): no structure available.
# CAS number '65996-91-0' (name = 'Distillates, coal tar, upper'): no structure available.
# CAS number '92045-58-4' (name = 'Naphtha, petroleum, isomerization, C6-fraction'): no structure available.
# CAS number '64743-01-7' (name = 'Petrolatum, petroleum, oxidized'): no structure available.
# CAS number '64741-61-3' (name = 'Distillates, petroleum, heavy catalytic cracked'): no structure available.
# CAS number '64741-80-6' (name = 'Residues, petroleum, thermal cracked'): no structure available.
# CAS number '68308-11-2' (name = 'Tail gas, petroleum, propane-propylene alkylation feed prep deethanizer'): no structure available.
# CAS number '64742-65-0' (name = 'Distillates, petroleum, solvent-dewaxed heavy paraffinic'): no structure available.
# CAS number '64741-92-0' (name = 'Naphtha, petroleum, solvent-refined heavy'): no structure available.
# CAS number '171090-93-0' (name = 'Benzenepropanoic acid, 3,5-bis(1,1-dimethylethyl)-4-hydroxy-, C13-15-branched and linear alkyl esters'): no structure available.
# CAS number '68333-28-8' (name = 'Distillates (petroleum), hydrodesulfurized heavy catalytic cracked'): no structure available.
# CAS number '68955-28-2' (name = 'Gases, petroleum, light steam-cracked, butadiene conc.'): no structure available.
# CAS number '92062-09-4' (name = 'Slack wax (petroleum), hydrotreated'): no structure available.
# CAS number '68477-91-8' (name = 'Gases, petroleum, depropanizer overheads'): no structure available.
# CAS number '68603-01-0' (name = 'Distillates, petroleum, thermal cracked naphtha and gas oil, C5-dimer-contg.'): no structure available.
# CAS number '72623-87-1' (name = 'Lubricating oils, petroleum, C20-50, hydrotreated neutral oil-based'): no structure available.
# CAS number '64741-87-3' (name = 'Naphtha, petroleum, sweetened'): no structure available.
# CAS number '64741-82-8' (name = 'Distillates, petroleum, light thermal cracked'): no structure available.
# CAS number '68131-49-7' (name = 'Aromatic hydrocarbons, C6-10, acid-treated, neutralized'): no structure available.
# CAS number '68477-69-0' (name = 'Gases, petroleum, butane splitter overheads'): no structure available.
# CAS number '68783-13-1' (name = 'Residues, petroleum, coker scrubber, condensed-ring-arom.-contg.'): no structure available.
# CAS number '68477-61-2' (name = 'Extracts (petroleum), cold-acid, C4-6'): no structure available.
# CAS number '68952-81-8' (name = 'Tail gas, petroleum, thermal-cracked distillate, gas oil and naphtha absorber'): no structure available.
# CAS number '64742-46-7' (name = 'Distillates, petroleum, hydrotreated middle'): no structure available.
# CAS number '64742-71-8' (name = 'Paraffin oils, petroleum, catalytic dewaxed light'): no structure available.
# CAS number '68477-50-9' (name = 'Distillates (petroleum), polymd. steam-cracked petroleum distillates, C5-12 fraction'): no structure available.
# CAS number '61788-46-3' (name = 'Amines, coco alkyl'): no structure available.
# 2281

# %%
comptox_df = pd.DataFrame(records)

comptox_df.shape
# Out:
# (2281, 7)

# %%
# Check for missing names or structures...

for x in ('name', 'inchi', 'inchikey', 'smiles'): assert (comptox_df[x].isnull() | (comptox_df[x] == '')).sum() == 0

# %%
# Add link to CompTox dashboard...

comptox_df['report'] = comptox_df['cas'].apply(comptox_link)

# %%
# Add RDKit molecule...

### PandasTools.AddMoleculeColumnToFrame(comptox_df, smilesCol='smiles', molCol='mol')

comptox_df['mol'] = [Chem.MolFromMolBlock(x) for x in comptox_df['conntab']]
comptox_df['MW'] = [Descriptors.MolWt(x) if not x == None else None for x in comptox_df['mol']]
comptox_df['logP'] = [Descriptors.MolLogP(x) if not x == None else None for x in comptox_df['mol']]
comptox_df['TPSA'] = [Descriptors.TPSA(x) if not x == None else None for x in comptox_df['mol']]

# %%
comptox_df.drop(['inchi', 'conntab', 'synonyms', 'mol'], axis=1).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-da12c103192a> in <module>()
# ----> 1 comptox_df.drop(['inchi', 'conntab', 'synonyms', 'mol'], axis=1).head()
#
# C:\Users\bet\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2048                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2049             else:
# -> 2050                 new_axis = axis.drop(labels, errors=errors)
#    2051             dropped = self.reindex(**{axis_name: new_axis})
#    2052             try:
#
# C:\Users\bet\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3573             if errors != 'ignore':
#    3574                 raise ValueError('labels %s not contained in axis' %
# -> 3575                                  labels[mask])
#    3576             indexer = indexer[~mask]
#    3577         return self.delete(indexer)
#
# ValueError: labels ['inchi' 'conntab' 'synonyms' 'mol'] not contained in axis

# %%
outFile = "C:\\Users\\bet\\Documents\\Inditex\\Compound inventory\\Annotated compounds\\REACH\\AnnexVI_inventory\\20170516\\annex_vi_clp_table_en.split.TallAndSkinny.smi_desc.tsv"
outF = open(outFile, 'w')
comptox_df.drop(['inchi', 'conntab', 'synonyms', 'mol'], axis=1, inplace=True)
comptox_df.to_csv(outFile, sep='\t', float_format='%.2f', index=False)
outF.close()
